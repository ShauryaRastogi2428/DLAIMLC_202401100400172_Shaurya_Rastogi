# %% [markdown]
# #Tensorflow

# %%
import tensorflow as tf
import numpy as np

#Step-1 -: Convert data to numpy arrays
x = np.array([1, 2, 3, 4], dtype = float)
y = np.array([2, 4, 6, 8], dtype = float)

#Step-2 -: Define model using Iput layer
model = tf.keras.Sequential([
    tf.keras.Input(shape = (1, )),
    tf.keras.layers.Dense(1)
])

#Step-3 -: Compile the model
model.compile(optimizer = 'sgd', loss = 'mean_squared_error')

#Step-4 -: Train the model
model.fit(x, y, epochs = 10)
# Out:
# Epoch 1/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 190ms/step - loss: 13.7653
# Epoch 2/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - loss: 9.5600
# Epoch 3/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - loss: 6.6420
# Epoch 4/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - loss: 4.6172
# Epoch 5/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 3.2122
# Epoch 6/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - loss: 2.2372
# Epoch 7/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - loss: 1.5606
# Epoch 8/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - loss: 1.0911
# Epoch 9/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - loss: 0.7653
# Epoch 10/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - loss: 0.5392

# %% [markdown]
# #Keras

# %%
import numpy as np
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

#Convert lists to numpy arrays
x = np.array([1, 2, 3, 4], dtype = float)
y = np.array([2, 4, 6, 8], dtype = float)

#Define the model
model = Sequential([
    Dense(1, input_shape = (1, ))
])

#Compile the model
model.compile(optimizer=  'sgd', loss = 'mse')

#Train the model
model.fit(x, y, epochs=10)
# Out:
# Epoch 1/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 316ms/step - loss: 25.7631
# Epoch 2/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - loss: 17.8924
# Epoch 3/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step - loss: 12.4311
# Epoch 4/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - loss: 8.6415
# Epoch 5/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - loss: 6.0119
# Epoch 6/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - loss: 4.1871
# Epoch 7/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - loss: 2.9209
# Epoch 8/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - loss: 2.0422
# Epoch 9/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - loss: 1.4324
# Epoch 10/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - loss: 1.0091

# %% [markdown]
# #Pytorch

# %%
import torch
import torch.nn as nn
import torch.optim as optim

# Define a simple linear model
model = nn.Linear(1, 1)

# Loss and optimizer
criterion = nn.MSELoss()
optimizer = optim.SGD(model.parameters(), lr=0.01)

# Dummy data (convert to float)
x = torch.tensor([[1.], [2.], [3.], [4.]])
y = torch.tensor([[2.], [4.], [6.], [8.]])

# Training loop
for epoch in range(10):
    optimizer.zero_grad()
    outputs = model(x)
    loss = criterion(outputs, y)
    loss.backward()
    optimizer.step()

    print(f"Epoch {epoch + 1}, Loss: {loss.item():.4f}")
# Out:
# Epoch 1, Loss: 8.6197
# Epoch 2, Loss: 6.0174
# Epoch 3, Loss: 4.2115
# Epoch 4, Loss: 2.9582
# Epoch 5, Loss: 2.0884
# Epoch 6, Loss: 1.4846
# Epoch 7, Loss: 1.0655
# Epoch 8, Loss: 0.7744
# Epoch 9, Loss: 0.5722
# Epoch 10, Loss: 0.4318
